# %%
import boto3

session = boto3.Session() # Grabs session details directly from aws configuration in EC2 instance running the Notebook server
session
# Out:
# Session(region_name='eu-central-1')

# %%
s3r = session.resource("s3")
s3r
# Out:
# s3.ServiceResource()

# %%
for bucket in s3r.buckets.all():
  print(bucket)
# Out:
# s3.Bucket(name='aida-project')
# s3.Bucket(name='cseng-1468-bucket')
# s3.Bucket(name='flutz-bucket')
# s3.Bucket(name='igeokce-s3quest')
# s3.Bucket(name='jgodley-q1468')
# s3.Bucket(name='jgodley-q1490')
# s3.Bucket(name='jpoliak-1468')
# s3.Bucket(name='jpoliak1394')
# s3.Bucket(name='jpoliak1490')
# s3.Bucket(name='mpensel-aida-live')
# s3.Bucket(name='niy-certification')
# s3.Bucket(name='njeno-auto-ml')
# s3.Bucket(name='peckert-1464-bucket')
# s3.Bucket(name='peckert-1490-automl')
# s3.Bucket(name='sagemaker-eu-central-1-898627427171')
# s3.Bucket(name='sagemaker-studio-898627427171-of0968vn9r')
# s3.Bucket(name='sharston')
# s3.Bucket(name='sjf-project')
# s3.Bucket(name='ye-1468')
# s3.Bucket(name='ye-1490')

# %%
bucket = s3r.Bucket('aida-project')
files=[]
for obj in bucket.objects.all():
  if obj.key.startswith("Covid"):
#    print(obj.key)
    if obj.key.endswith("csv"):
        files.append(obj.key)
for file in files:
    print(file)
# Out:
# Covid-19/1/owid-covid-data.csv
# Covid-19/2/covid-19-at.csv
# Covid-19/2/covid-19-be.csv
# Covid-19/2/covid-19-ch.csv
# Covid-19/2/covid-19-cz.csv
# Covid-19/2/covid-19-de.csv
# Covid-19/2/covid-19-ecdc.csv
# Covid-19/2/covid-19-england.csv
# Covid-19/2/covid-19-fr.csv
# Covid-19/2/covid-19-hu.csv
# Covid-19/2/covid-19-ie.csv
# Covid-19/2/covid-19-it.csv
# Covid-19/2/covid-19-nl.csv
# Covid-19/2/covid-19-no.csv
# Covid-19/2/covid-19-pl.csv
# Covid-19/2/covid-19-scotland.csv
# Covid-19/2/covid-19-se.csv
# Covid-19/2/covid-19-si.csv
# Covid-19/2/covid-19-uk.csv
# Covid-19/2/covid-19-wales.csv
# Covid-19/3/time_series_covid19_confirmed_US.csv
# Covid-19/3/time_series_covid19_confirmed_global.csv
# Covid-19/3/time_series_covid19_deaths_US.csv
# Covid-19/3/time_series_covid19_deaths_global.csv
# Covid-19/3/time_series_covid19_recovered_global.csv
# Covid-19/4/covid_jpn_metadata.csv
# Covid-19/4/covid_jpn_prefecture.csv
# Covid-19/4/covid_jpn_total.csv
# Covid-19/5/brazil_cities_coordinates.csv
# Covid-19/5/brazil_covid19.csv
# Covid-19/5/brazil_covid19_cities.csv
# Covid-19/5/brazil_covid19_macro.csv
# Covid-19/5/brazil_covid19_old.csv
# Covid-19/5/brazil_population_2019.csv
# Covid-19/6/StatewiseTestingDetails.csv
# Covid-19/6/covid_19_india.csv

# %%
def df_investigate(df):
  info = pd.DataFrame(df.count(), columns=['filled'])
  info['filled %'] = round(info['filled'] / len(df), 4)*100
  info['nunique'] = df.nunique()
  info['uniques'] = np.nan
  info['dtypes'] = df.dtypes
  for idx, row in info.iterrows():
    if row['nunique'] < 10:
      info.loc[idx, 'uniques'] = str(list(df[idx].unique()))
  return info

# %%
import pandas as pd
import numpy as np
cols={}
investigation={}
for i in range(len(files)):
    nstars=62 - len(files[i])
    print((nstars + 4)*'*')
    print('* ',files[i],' *')
    print((nstars + 4)*'*')
    file_check = "s3://" + bucket.name + "/" + files[i]

    # get the training data
    df = pd.read_csv(file_check)
    
    """
    print(df.head(3))
    print("\n",30*'=')
    print('   Investigation')
    print(30*'=',"\n")
    """
    
    inv = df_investigate(df)
    investigation[files[i]]=inv
    cols[files[i]] = df.columns.values.tolist()
# Out:
# ************************************
# *  Covid-19/1/owid-covid-data.csv  *
# ************************************
# ****************************************
# *  Covid-19/2/covid-19-at.csv  *
# ****************************************
# ****************************************
# *  Covid-19/2/covid-19-be.csv  *
# ****************************************
# ****************************************
# *  Covid-19/2/covid-19-ch.csv  *
# ****************************************
# ****************************************
# *  Covid-19/2/covid-19-cz.csv  *
# ****************************************
# ****************************************
# *  Covid-19/2/covid-19-de.csv  *
# ****************************************
# **************************************
# *  Covid-19/2/covid-19-ecdc.csv  *
# **************************************
# ***********************************
# *  Covid-19/2/covid-19-england.csv  *
# ***********************************
# ****************************************
# *  Covid-19/2/covid-19-fr.csv  *
# ****************************************
# ****************************************
# *  Covid-19/2/covid-19-hu.csv  *
# ****************************************
# ****************************************
# *  Covid-19/2/covid-19-ie.csv  *
# ****************************************
# ****************************************
# *  Covid-19/2/covid-19-it.csv  *
# ****************************************
# ****************************************
# *  Covid-19/2/covid-19-nl.csv  *
# ****************************************
# ****************************************
# *  Covid-19/2/covid-19-no.csv  *
# ****************************************
# ****************************************
# *  Covid-19/2/covid-19-pl.csv  *
# ****************************************
# **********************************
# *  Covid-19/2/covid-19-scotland.csv  *
# **********************************
# ****************************************
# *  Covid-19/2/covid-19-se.csv  *
# ****************************************
# ****************************************
# *  Covid-19/2/covid-19-si.csv  *
# ****************************************
# ****************************************
# *  Covid-19/2/covid-19-uk.csv  *
# ****************************************
# *************************************
# *  Covid-19/2/covid-19-wales.csv  *
# *************************************
# *******************
# *  Covid-19/3/time_series_covid19_confirmed_US.csv  *
# *******************
# ***************
# *  Covid-19/3/time_series_covid19_confirmed_global.csv  *
# ***************
# **********************
# *  Covid-19/3/time_series_covid19_deaths_US.csv  *
# **********************
# ******************
# *  Covid-19/3/time_series_covid19_deaths_global.csv  *
# ******************
# ***************
# *  Covid-19/3/time_series_covid19_recovered_global.csv  *
# ***************
# *********************************
# *  Covid-19/4/covid_jpn_metadata.csv  *
# *********************************
# *******************************
# *  Covid-19/4/covid_jpn_prefecture.csv  *
# *******************************
# ************************************
# *  Covid-19/4/covid_jpn_total.csv  *
# ************************************
# **************************
# *  Covid-19/5/brazil_cities_coordinates.csv  *
# **************************
# *************************************
# *  Covid-19/5/brazil_covid19.csv  *
# *************************************
# ******************************
# *  Covid-19/5/brazil_covid19_cities.csv  *
# ******************************
# *******************************
# *  Covid-19/5/brazil_covid19_macro.csv  *
# *******************************
# *********************************
# *  Covid-19/5/brazil_covid19_old.csv  *
# *********************************
# *****************************
# *  Covid-19/5/brazil_population_2019.csv  *
# *****************************
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-64-13cd6ead5a5a> in <module>
#      11
#      12     # get the training data
# ---> 13     df = pd.read_csv(file_check)
#      14
#      15     """
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     try:
# --> 454         data = parser.read(nrows)
#     455     finally:
#     456         parser.close()
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2035     def read(self, nrows=None):
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#    2039             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 8 fields in line 1282, saw 9

# %%
for i in range(1,20):
    print(files[i],"\n",cols[files[i]])
# Out:
# Covid-19/2/covid-19-at.csv
#  ['country', 'nuts_2', 'cases', 'recovered', 'deaths', 'tests', 'hospitalized', 'intensive_care', 'datetime']
# Covid-19/2/covid-19-be.csv
#  ['country', 'nuts_1', 'nuts_2', 'cases', 'deaths', 'hospitalized', 'intensive_care', 'datetime']
# Covid-19/2/covid-19-ch.csv
#  ['country', 'nuts_3', 'nuts_3_code', 'cases', 'deaths', 'tests', 'hospitalized', 'intensive_care', 'datetime']
# Covid-19/2/covid-19-cz.csv
#  ['country', 'nuts_3', 'cases', 'datetime']
# Covid-19/2/covid-19-de.csv
#  ['country', 'nuts_1', 'cases', 'cases/100k pop.', 'deaths', 'datetime']
# Covid-19/2/covid-19-ecdc.csv
#  ['country', 'cases', 'deaths', 'datetime']
# Covid-19/2/covid-19-england.csv
#  ['country', 'nuts_3', 'cases', 'datetime']
# Covid-19/2/covid-19-fr.csv
#  ['country', 'nuts_2', 'cases', 'datetime']
# Covid-19/2/covid-19-hu.csv
#  ['country', 'cases', 'recovered', 'deaths', 'tests', 'quarantine', 'datetime']
# Covid-19/2/covid-19-ie.csv
#  ['country', 'lau', 'cases', 'datetime']
# Covid-19/2/covid-19-it.csv
#  ['country', 'nuts_2', 'nuts_3', 'cases', 'datetime']
# Covid-19/2/covid-19-nl.csv
#  ['country', 'lau', 'cases', 'population', 'cases/100k pop.', 'deaths', 'hospitalized', 'hospitalized/100k pop.', 'datetime']
# Covid-19/2/covid-19-no.csv
#  ['country', 'nuts_3', 'cases', 'cases/100k pop.', 'datetime']
# Covid-19/2/covid-19-pl.csv
#  ['country', 'nuts_2', 'cases', 'deaths', 'datetime']
# Covid-19/2/covid-19-scotland.csv
#  ['country', 'nuts_3', 'cases', 'hospitalized', 'intensive_care', 'datetime']
# Covid-19/2/covid-19-se.csv
#  ['country', 'nuts_3', 'cases', 'cases/100k pop.', 'percent', 'deaths', 'intensive_care', 'datetime']
# Covid-19/2/covid-19-si.csv
#  ['country', 'cases', 'deaths', 'tests', 'tests_positive', 'hospitalized', 'intensive_care', 'datetime']
# Covid-19/2/covid-19-uk.csv
#  ['country', 'nuts_3', 'cases', 'cases_lower', 'cases_upper', 'datetime']
# Covid-19/2/covid-19-wales.csv
#  ['country', 'nuts_3', 'cases', 'datetime']

# %%
investigation
# Out:
# {'Covid-19/1/owid-covid-data.csv':                                     filled  filled %  nunique  \
#  iso_code                             59637     99.44      215
#  continent                            59302     98.88        6
#  location                             59972    100.00      216
#  date                                 59972    100.00      335
#  total_cases                          56322     93.91    24041
#  new_cases                            59021     98.41     5801
#  new_cases_smoothed                   58222     97.08    12186
#  total_deaths                         46685     77.84     8181
#  new_deaths                           59021     98.41     1265
#  new_deaths_smoothed                  58222     97.08     2930
#  total_cases_per_million              56023     93.42    39474
#  new_cases_per_million                58957     98.31    21767
#  new_cases_smoothed_per_million       58157     96.97    25026
#  total_deaths_per_million             46401     77.37    21286
#  new_deaths_per_million               58957     98.31     4145
#  new_deaths_smoothed_per_million      58157     96.97     4936
#  reproduction_rate                    38758     64.63      361
#  icu_patients                          4747      7.92     1308
#  icu_patients_per_million              4747      7.92     2443
#  hosp_patients                         5421      9.04     2266
#  hosp_patients_per_million             5421      9.04     3752
#  weekly_icu_admissions                  444      0.74      305
#  weekly_icu_admissions_per_million      444      0.74      299
#  weekly_hosp_admissions                 731      1.22      624
#  weekly_hosp_admissions_per_million     731      1.22      621
#  total_tests                          23503     39.19    22778
#  new_tests                            23369     38.97    13260
#  total_tests_per_thousand             23503     39.19    19199
#  new_tests_per_thousand               23369     38.97     4155
#  new_tests_smoothed                   25991     43.34    14617
#  new_tests_smoothed_per_thousand      25991     43.34     4259
#  tests_per_case                       24095     40.18    20298
#  positive_rate                        24507     40.86      550
#  tests_units                          26971     44.97        6
#  stringency_index                     48463     80.81      172
#  population                           59637     99.44      215
#  population_density                   56793     94.70      203
#  median_age                           53288     88.85      134
#  aged_65_older                        52483     87.51      185
#  aged_70_older                        53010     88.39      184
#  gdp_per_capita                       52597     87.70      187
#  extreme_poverty                      35054     58.45       75
#  cardiovasc_death_rate                53281     88.84      189
#  diabetes_prevalence                  55231     92.09      144
#  female_smokers                       41373     68.99      107
#  male_smokers                         40843     68.10      123
#  handwashing_facilities               25316     42.21       95
#  hospital_beds_per_thousand           47940     79.94      100
#  life_expectancy                      58866     98.16      200
#  human_development_index              51429     85.76      157
#
#                                                                                uniques  \
#  iso_code                                                                          NaN
#  continent                           ['North America', 'Asia', 'Africa', 'Europe', ...
#  location                                                                          NaN
#  date                                                                              NaN
#  total_cases                                                                       NaN
#  new_cases                                                                         NaN
#  new_cases_smoothed                                                                NaN
#  total_deaths                                                                      NaN
#  new_deaths                                                                        NaN
#  new_deaths_smoothed                                                               NaN
#  total_cases_per_million                                                           NaN
#  new_cases_per_million                                                             NaN
#  new_cases_smoothed_per_million                                                    NaN
#  total_deaths_per_million                                                          NaN
#  new_deaths_per_million                                                            NaN
#  new_deaths_smoothed_per_million                                                   NaN
#  reproduction_rate                                                                 NaN
#  icu_patients                                                                      NaN
#  icu_patients_per_million                                                          NaN
#  hosp_patients                                                                     NaN
#  hosp_patients_per_million                                                         NaN
#  weekly_icu_admissions                                                             NaN
#  weekly_icu_admissions_per_million                                                 NaN
#  weekly_hosp_admissions                                                            NaN
#  weekly_hosp_admissions_per_million                                                NaN
#  total_tests                                                                       NaN
#  new_tests                                                                         NaN
#  total_tests_per_thousand                                                          NaN
#  new_tests_per_thousand                                                            NaN
#  new_tests_smoothed                                                                NaN
#  new_tests_smoothed_per_thousand                                                   NaN
#  tests_per_case                                                                    NaN
#  positive_rate                                                                     NaN
#  tests_units                         [nan, 'tests performed', 'units unclear', 'peo...
#  stringency_index                                                                  NaN
#  population                                                                        NaN
#  population_density                                                                NaN
#  median_age                                                                        NaN
#  aged_65_older                                                                     NaN
#  aged_70_older                                                                     NaN
#  gdp_per_capita                                                                    NaN
#  extreme_poverty                                                                   NaN
#  cardiovasc_death_rate                                                             NaN
#  diabetes_prevalence                                                               NaN
#  female_smokers                                                                    NaN
#  male_smokers                                                                      NaN
#  handwashing_facilities                                                            NaN
#  hospital_beds_per_thousand                                                        NaN
#  life_expectancy                                                                   NaN
#  human_development_index                                                           NaN
#
#                                       dtypes
#  iso_code                             object
#  continent                            object
#  location                             object
#  date                                 object
#  total_cases                         float64
#  new_cases                           float64
#  new_cases_smoothed                  float64
#  total_deaths                        float64
#  new_deaths                          float64
#  new_deaths_smoothed                 float64
#  total_cases_per_million             float64
#  new_cases_per_million               float64
#  new_cases_smoothed_per_million      float64
#  total_deaths_per_million            float64
#  new_deaths_per_million              float64
#  new_deaths_smoothed_per_million     float64
#  reproduction_rate                   float64
#  icu_patients                        float64
#  icu_patients_per_million            float64
#  hosp_patients                       float64
#  hosp_patients_per_million           float64
#  weekly_icu_admissions               float64
#  weekly_icu_admissions_per_million   float64
#  weekly_hosp_admissions              float64
#  weekly_hosp_admissions_per_million  float64
#  total_tests                         float64
#  new_tests                           float64
#  total_tests_per_thousand            float64
#  new_tests_per_thousand              float64
#  new_tests_smoothed                  float64
#  new_tests_smoothed_per_thousand     float64
#  tests_per_case                      float64
#  positive_rate                       float64
#  tests_units                          object
#  stringency_index                    float64
#  population                          float64
#  population_density                  float64
#  median_age                          float64
#  aged_65_older                       float64
#  aged_70_older                       float64
#  gdp_per_capita                      float64
#  extreme_poverty                     float64
#  cardiovasc_death_rate               float64
#  diabetes_prevalence                 float64
#  female_smokers                      float64
#  male_smokers                        float64
#  handwashing_facilities              float64
#  hospital_beds_per_thousand          float64
#  life_expectancy                     float64
#  human_development_index             float64  ,
#  'Covid-19/2/covid-19-at.csv':                 filled  filled %  nunique  \
#  country           7278    100.00        1
#  nuts_2            6591     90.56        9
#  cases             7278    100.00     3510
#  recovered         6929     95.20     1846
#  deaths            6929     95.20      492
#  tests             6670     91.65     2269
#  hospitalized      6870     94.39      477
#  intensive_care    6870     94.39      202
#  datetime          7278    100.00      735
#
#                                                            uniques   dtypes
#  country                                                    ['AT']   object
#  nuts_2          ['Tirol', 'Salzburg', 'Steiermark', 'Niederöst...   object
#  cases                                                         NaN    int64
#  recovered                                                     NaN  float64
#  deaths                                                        NaN  float64
#  tests                                                         NaN  float64
#  hospitalized                                                  NaN  float64
#  intensive_care                                                NaN  float64
#  datetime                                                      NaN   object  }
